# %% [markdown]
# Contents
# 1. Import libraries
# 2. Import orders_products_combined df
# 3. Drop merge flag
# 4. Check df shape
# 5. Drop unnamed column
# 6. Merge columns
# 7. Export as pickle

# %% [markdown]
# 1. Import libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
#Define path
path = '/Users/wenboyang/Desktop/Data Analytics/05-08-2023 Instacart Basket Analysis /02 Data/'

# %% [markdown]
# 2. Import orders_products_combined

# %%
#Import orders_products_combined dataframe 
pkl_data = os.path.join(path, 'Prepared Data','orders_products_combined.pkl')

# %%
df = pd.read_pickle(pkl_data)

# %%
df
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 0          2539329        1             1                   2
# 1          2539329        1             1                   2
# 2          2539329        1             1                   2
# 3          2539329        1             1                   2
# 4          2539329        1             1                   2
# ...            ...      ...           ...                 ...
# 32434484   2977660   206209            13                   1
# 32434485   2977660   206209            13                   1
# 32434486   2977660   206209            13                   1
# 32434487   2977660   206209            13                   1
# 32434488   2977660   206209            13                   1
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     NaN         196
# 1                         8                     NaN       14084
# ...

# %% [markdown]
# 3. Drop merge flag

# %%
#Drop merge flag 
df = df.drop(columns = '_merge')

# %%
df
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 0          2539329        1             1                   2
# 1          2539329        1             1                   2
# 2          2539329        1             1                   2
# 3          2539329        1             1                   2
# 4          2539329        1             1                   2
# ...            ...      ...           ...                 ...
# 32434484   2977660   206209            13                   1
# 32434485   2977660   206209            13                   1
# 32434486   2977660   206209            13                   1
# 32434487   2977660   206209            13                   1
# 32434488   2977660   206209            13                   1
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     NaN         196
# 1                         8                     NaN       14084
# ...

# %% [markdown]
# 4. Check shape

# %%
#Step 4 Check shape 
df.shape
# Out:
# (32434489, 9)

# %%
#Import products data 
prods_data = os.path.join(path, 'Prepared Data', 'prods_checked.csv')

# %%
df_prods = pd.read_csv(prods_data)

# %%
df_prods
# Out:
#        Unnamed: 0  product_id  \
# 0               0           1
# 1               1           2
# 2               2           3
# 3               3           4
# 4               4           5
# ...           ...         ...
# 49667       49688       49684
# 49668       49689       49685
# 49669       49690       49686
# 49670       49691       49687
# 49671       49692       49688
#
#                                             product_name  aisle_id  \
# 0                             Chocolate Sandwich Cookies        61
# 1                                       All-Seasons Salt       104
# 2                   Robust Golden Unsweetened Oolong Tea        94
# 3      Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4                              Green Chile Anytime Sauce         5
# ...                                                  ...       ...
# 49667          Vodka, Triple Distilled, Twist of Vanilla       124
# ...

# %% [markdown]
# 5. Drop unnamed column

# %%
# Drop unnamed column for df_prods
df_prods = df_prods.drop(columns = ['Unnamed: 0'])

# %%
df_prods
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49667       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49668       49685                 En Croute Roast Hazelnut Cranberry
# 49669       49686                                   Artisan Baguette
# 49670       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49671       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices
# 0            61             19     5.8
# 1           104             13     9.3
# ...

# %%
#Check shape 
df_prods.shape
# Out:
# (49672, 5)

# %% [markdown]
# 6. Merge df_prods with orders_products_combined

# %%
#merge the two dfs 
df_merged = df.merge(df_prods, on = 'product_id', indicator = True)

# %%
#check merge results 
df_merged.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge
# 0         Soda        77              7     9.0   both
# ...

# %%
 df_merged['_merge'].value_counts()
# Out:
# both          32404859
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %%
#Check df_merged shape
df_merged.shape
# Out:
# (32404859, 14)

# %% [markdown]
# 7. Export df

# %%
#Export the newly created dataframe as orders_products_merged in a suitable format:
df_merged.to_pickle(os.path.join(path, 'Prepared Data', 'orders_products_merged.pkl'))
